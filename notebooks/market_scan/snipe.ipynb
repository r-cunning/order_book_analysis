# %%
import pandas as pd
import math

# %%
from datetime import datetime

def is_minute_multiple_of_five():
    """
    Check if the current minute is a multiple of 5.
    
    :return: True if the current minute is a multiple of 5, otherwise False.
    """
    current_minute = datetime.now().minute
    return current_minute % 5 == 0

# %%
import os
import time
import json
import requests
import pandas as pd
from datetime import datetime
from requests.exceptions import HTTPError

# Constants
jita_station_id = 60003760  # Jita IV - Moon 4 - Caldari Navy Assembly Plant
base_url = "https://esi.evetech.net/latest"

def get_market_orders_jita(page=1):
    """
    Fetch market orders for Jita from ESI API.
    
    :param page: Page number for pagination.
    :return: JSON response containing market orders.
    """
    url = f"{base_url}/markets/10000002/orders/"
    params = {
        "order_type": "sell",
        "page": page,
        "structure_id": jita_station_id
    }
    
    response = requests.get(url, params=params)
    response.raise_for_status()  # This will raise an HTTPError for bad responses
    
    return response.json()

def download_all_orders():
    """
    Download all sell orders from Jita.
    
    :return: A list containing all market orders.
    """
    all_orders = []
    page = 1

    while True:
        try:
            orders = get_market_orders_jita(page)
            if not orders:
                break
            all_orders.extend(orders)
            print(f"Fetched page {page}, orders: {len(orders)}")
            page += 1
            time.sleep(1)  # Be polite to the API, limit request rate
        except HTTPError as e:
            if e.response.status_code == 404:
                print(f"Page {page} not found. Ending download.")
                break
            else:
                raise  # Re-raise the exception if it's not a 404 error
    
    return all_orders

# %%
raw_data = pd.read_csv('data/eve_ref_market_orders/latest/market-orders-latest.v3.csv')

# %%
# Download all orders
# orders = download_all_orders()

# Convert the list of orders to a DataFrame
# raw_data = pd.DataFrame(orders)

# # Get the current date and time
# current_datetime = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# # Create the directory if it doesn't exist
# output_dir = f'data/{current_datetime}'
# os.makedirs(output_dir, exist_ok=True)

# # Save the DataFrame to a CSV file in the directory
# output_file = f"{output_dir}/jita_sell_orders.csv"
# # raw_data.to_csv(output_file, index=False)

# print(f"Total orders downloaded: {len(orders)}")
# print(f"Orders saved to {output_file}")

# %%
def snipe(orders, type_id, station_id, sell_spread_threshold = 0.5, profit_margin=0, cost_threshold = math.inf):
    # get all orders for type_id
    # orders = data[data['type_id'] == type_id]
    # get the lowest sell order
    snipe_found = False
    trade_dict = {}

    # Filter orders for sell orders
    sell_orders = orders[orders['is_buy_order'] == False].sort_values(by='price', ascending=True)
    buy_orders = orders[orders['is_buy_order'] == True].sort_values(by='price', ascending=False)
    if sell_orders.empty or buy_orders.empty:
        # print(f"No sell orders found for type_id {type_id} at station {station_id}")
        return False  
    else:
        
        
        
        
        lowest_sell_price = sell_orders['price'].min()
        lowest_sell_volume = sell_orders['volume_remain'].iloc[0]
        
        if len(sell_orders) == 1:
            second_lowest_sell_price = lowest_sell_price
        else:
            second_lowest_sell_price = sell_orders['price'].iloc[1]
        
        highest_buy_price = buy_orders['price'].max()

            
        spread = abs(highest_buy_price - lowest_sell_price)
        difference_to_next_sell = abs(second_lowest_sell_price - lowest_sell_price)

        # check if the spread between buy/sell is smaller than the spread between the lowest sell and the second lowest sell
        # if TRUE then we have a snipe - we can buy at the lowest sell price and relist for an easy profit (in theory)
        # This should be more dynamic than simply checking for an exact match between the buy/sell spread 
        margin = second_lowest_sell_price - lowest_sell_price

        profit = margin*lowest_sell_volume
        
        cost = lowest_sell_price*lowest_sell_volume
        
        if spread < (difference_to_next_sell * sell_spread_threshold) and profit > profit_margin and cost < cost_threshold or lowest_sell_price == highest_buy_price and profit > profit_margin and cost < cost_threshold:

            trade_dict['type_id'] = type_id
            trade_dict['station_id'] = station_id
            trade_dict['profit'] = profit
            trade_dict['cost'] = cost
            
            
            
            # volume = orders[orders['is_buy_order'] == False]['volume'].sum()
            print("--------------------------------------------------------------------------")
            print(f"Type ID {type_id} is a snipe at station: {station_id}.") 
            print(f"Profit: {profit} ISK || Cost: {cost} ISK")
            print(f"Lowest sell: {lowest_sell_price} Highest buy: {highest_buy_price} volume: {lowest_sell_volume}") 
            print(f"Second sell: {second_lowest_sell_price} ~ Margin: {margin} ISK")
            print("--------------------------------------------------------------------------")

                        
            return trade_dict
        else:
            return trade_dict

# %%
def filter_data(data, station_id, sell_spread_threshold=0.8, profit_margin=0, cost_threshold=math.inf):

    # data = data[data['location_id'] == station_id]
    station_ids = data['location_id'].unique()
    type_ids = data['type_id'].unique()
    # for station_id in station_ids:
    station_data = data[data['location_id'] == station_id]
    snipeFound = False
    
    snipes = []
    
    for type_id in type_ids:
        orders = station_data[station_data['type_id'] == type_id]
        snipe_dict = snipe(orders, type_id, station_id, sell_spread_threshold=sell_spread_threshold, profit_margin=profit_margin, cost_threshold=cost_threshold)
        snipes.append(snipe_dict)
    if not snipes:
            print("          No snipes found. Back to sleep.")
            print("==========================================")
    return snipes

# %%
station_ids = {
    'Amarr': 60008494,
    'Jita': 60003760,
    # 'Dodixie': 60011866,
    # 'Hek': 60005686,
    # 'Rens': 60004588
}

# %%
for station_name, station_id in station_ids.items():

    print("=====================================")
    print(f"Checking for snipes at hub: {station_name}")
    print("=====================================")
    snipes = filter_data(raw_data, station_id,sell_spread_threshold=0.8, profit_margin = 100000, cost_threshold = 5000000)
# Out:
# =====================================
# Checking for snipes at hub: Jita
# =====================================
# --------------------------------------------------------------------------
# Type ID 195 is a snipe at station: 60003760.
# Profit: 154326.00000000003 ISK || Cost: 272785.0 ISK
# Lowest sell: 30.65 Highest buy: 30.51 volume: 8900
# Second sell: 47.99 ~ Margin: 17.340000000000003 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 197 is a snipe at station: 60003760.
# Profit: 863820.0 ISK || Cost: 207000.0 ISK
# Lowest sell: 115.0 Highest buy: 60.0 volume: 1800
# Second sell: 594.9 ~ Margin: 479.9 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 215 is a snipe at station: 60003760.
# Profit: 1396335.6000000003 ISK || Cost: 2086040.7599999998 ISK
# Lowest sell: 4.93 Highest buy: 4.73 volume: 423132
# Second sell: 8.23 ~ Margin: 3.3000000000000007 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 598 is a snipe at station: 60003760.
# Profit: 17085000.0 ISK || Cost: 3500000.0 ISK
# Lowest sell: 700000.0 Highest buy: 458500.0 volume: 5
# Second sell: 4117000.0 ~ Margin: 3417000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 653 is a snipe at station: 60003760.
# Profit: 532000.0 ISK || Cost: 1467000.0 ISK
# Lowest sell: 1467000.0 Highest buy: 1216000.0 volume: 1
# Second sell: 1999000.0 ~ Margin: 532000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 8419 is a snipe at station: 60003760.
# Profit: 164550.0 ISK || Cost: 209550.0 ISK
# Lowest sell: 69850.0 Highest buy: 39850.0 volume: 3
# Second sell: 124700.0 ~ Margin: 54850.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 11133 is a snipe at station: 60003760.
# Profit: 57660000.0 ISK || Cost: 1800000.0 ISK
# Lowest sell: 300000.0 Highest buy: 1000.0 volume: 6
# Second sell: 9910000.0 ~ Margin: 9610000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 11870 is a snipe at station: 60003760.
# Profit: 8000000.0 ISK || Cost: 4000000.0 ISK
# Lowest sell: 1000000.0 Highest buy: 111100.0 volume: 4
# Second sell: 3000000.0 ~ Margin: 2000000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 11872 is a snipe at station: 60003760.
# Profit: 4000000.0 ISK || Cost: 2000000.0 ISK
# Lowest sell: 1000000.0 Highest buy: 111100.0 volume: 2
# Second sell: 3000000.0 ~ Margin: 2000000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 15604 is a snipe at station: 60003760.
# Profit: 198000.0 ISK || Cost: 3002000.0 ISK
# Lowest sell: 1501000.0 Highest buy: 1500000.0 volume: 2
# Second sell: 1600000.0 ~ Margin: 99000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 15648 is a snipe at station: 60003760.
# Profit: 1898000.0 ISK || Cost: 999000.0 ISK
# Lowest sell: 999000.0 Highest buy: 130000.0 volume: 1
# Second sell: 2897000.0 ~ Margin: 1898000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 16186 is a snipe at station: 60003760.
# Profit: 742400.0 ISK || Cost: 257400.0 ISK
# Lowest sell: 128700.0 Highest buy: 1801.0 volume: 2
# Second sell: 499900.0 ~ Margin: 371200.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 16359 is a snipe at station: 60003760.
# Profit: 217600.0 ISK || Cost: 2380000.0 ISK
# Lowest sell: 140000.0 Highest buy: 135200.0 volume: 17
# Second sell: 152800.0 ~ Margin: 12800.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 28365 is a snipe at station: 60003760.
# Profit: 624800.0 ISK || Cost: 2186487.6 ISK
# Lowest sell: 699.9 Highest buy: 610.0 volume: 3124
# Second sell: 899.9 ~ Margin: 200.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 31142 is a snipe at station: 60003760.
# Profit: 3375000.0 ISK || Cost: 575000.0 ISK
# Lowest sell: 115000.0 Highest buy: 111.0 volume: 5
# Second sell: 790000.0 ~ Margin: 675000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 31681 is a snipe at station: 60003760.
# Profit: 5055000.0 ISK || Cost: 345000.0 ISK
# Lowest sell: 115000.0 Highest buy: 50210.0 volume: 3
# Second sell: 1800000.0 ~ Margin: 1685000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 33270 is a snipe at station: 60003760.
# Profit: 1500000.0 ISK || Cost: 1000000.0 ISK
# Lowest sell: 1000000.0 Highest buy: 2.0 volume: 1
# Second sell: 2500000.0 ~ Margin: 1500000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 34419 is a snipe at station: 60003760.
# Profit: 8049000.0 ISK || Cost: 1000000.0 ISK
# Lowest sell: 1000000.0 Highest buy: 77000.0 volume: 1
# Second sell: 9049000.0 ~ Margin: 8049000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 43699 is a snipe at station: 60003760.
# Profit: 1619100.0 ISK || Cost: 1079100.0 ISK
# Lowest sell: 119900.0 Highest buy: 60050.0 volume: 9
# Second sell: 299800.0 ~ Margin: 179900.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 45493 is a snipe at station: 60003760.
# Profit: 397800.0 ISK || Cost: 1768000.0 ISK
# Lowest sell: 1000.0 Highest buy: 820.2 volume: 1768
# Second sell: 1225.0 ~ Margin: 225.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 45502 is a snipe at station: 60003760.
# Profit: 711110.0 ISK || Cost: 712890.0 ISK
# Lowest sell: 8010.0 Highest buy: 2000.0 volume: 89
# Second sell: 16000.0 ~ Margin: 7990.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID
.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 32858 is a snipe at station: 60003760.
# Profit: 9996000.0 ISK || Cost: 4999000.0 ISK
# Lowest sell: 999800.0 Highest buy: 140000.0 volume: 5
# Second sell: 2999000.0 ~ Margin: 1999200.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 33034 is a snipe at station: 60003760.
# Profit: 1648994.0 ISK || Cost: 1006.0 ISK
# Lowest sell: 1006.0 Highest buy: 1005.0 volume: 1
# Second sell: 1650000.0 ~ Margin: 1648994.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 33055 is a snipe at station: 60003760.
# Profit: 1487000.0 ISK || Cost: 500000.0 ISK
# Lowest sell: 500000.0 Highest buy: 200100.0 volume: 1
# Second sell: 1987000.0 ~ Margin: 1487000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 34394 is a snipe at station: 60003760.
# Profit: 279900.0 ISK || Cost: 500100.0 ISK
# Lowest sell: 500100.0 Highest buy: 500000.0 volume: 1
# Second sell: 780000.0 ~ Margin: 279900.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 34417 is a snipe at station: 60003760.
# Profit: 1092000.0 ISK || Cost: 100000.0 ISK
# Lowest sell: 100000.0 Highest buy: 51020.0 volume: 1
# Second sell: 1192000.0 ~ Margin: 1092000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 37588 is a snipe at station: 60003760.
# Profit: 5601000.0 ISK || Cost: 3899000.0 ISK
# Lowest sell: 3899000.0 Highest buy: 350600.0 volume: 1
# Second sell: 9500000.0 ~ Margin: 5601000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 41266 is a snipe at station: 60003760.
# Profit: 183183.0 ISK || Cost: 78260.0 ISK
# Lowest sell: 860.0 Highest buy: 855.1 volume: 91
# Second sell: 2873.0 ~ Margin: 2013.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 41302 is a snipe at station: 60003760.
# Profit: 144900.0 ISK || Cost: 126000.0 ISK
# Lowest sell: 1000.0 Highest buy: 106.0 volume: 126
# Second sell: 2150.0 ~ Margin: 1150.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 41303 is a snipe at station: 60003760.
# Profit: 250740.0 ISK || Cost: 126000.0 ISK
# Lowest sell: 1000.0 Highest buy: 400.0 volume: 126
# Second sell: 2990.0 ~ Margin: 1990.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 45899 is a snipe at station: 60003760.
# Profit: 4148000.0 ISK || Cost: 3800000.0 ISK
# Lowest sell: 950000.0 Highest buy: 150000.0 volume: 4
# Second sell: 1987000.0 ~ Margin: 1037000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 46723 is a snipe at station: 60003760.
# Profit: 1198000.0 ISK || Cost: 2000000.0 ISK
# Lowest sell: 1000000.0 Highest buy: 790100.0 volume: 2
# Second sell: 1599000.0 ~ Margin: 599000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 46884 is a snipe at station: 60003760.
# Profit: 1798000.0 ISK || Cost: 2000000.0 ISK
# Lowest sell: 1000000.0 Highest buy: 700000.0 volume: 2
# Second sell: 1899000.0 ~ Margin: 899000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 47043 is a snipe at station: 60003760.
# Profit: 1112000.0 ISK || Cost: 870000.0 ISK
# Lowest sell: 870000.0 Highest buy: 19010.0 volume: 1
# Second sell: 1982000.0 ~ Margin: 1112000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 47729 is a snipe at station: 60003760.
# Profit: 888300.0 ISK || Cost: 3987900.0 ISK
# Lowest sell: 31650.0 Highest buy: 29280.0 volume: 126
# Second sell: 38700.0 ~ Margin: 7050.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 47733 is a snipe at station: 60003760.
# Profit: 116559.0 ISK || Cost: 729081.0 ISK
# Lowest sell: 9001.0 Highest buy: 9000.0 volume: 81
# Second sell: 10440.0 ~ Margin: 1439.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 47799 is a snipe at station: 60003760.
# Profit: 245940.0 ISK || Cost: 300000.0 ISK
# Lowest sell: 50000.0 Highest buy: 20200.0 volume: 6
# Second sell: 90990.0 ~ Margin: 40990.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 48775 is a snipe at station: 60003760.
# Profit: 1196000.0 ISK || Cost: 4000.0 ISK
# Lowest sell: 1000.0 Highest buy: 23.02 volume: 4
# Second sell: 300000.0 ~ Margin: 299000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 49723 is a snipe at station: 60003760.
# Profit: 164700.0 ISK || Cost: 403800.0 ISK
# Lowest sell: 134600.0 Highest buy: 125500.0 volume: 3
# Second sell: 189500.0 ~ Margin: 54900.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 49724 is a snipe at station: 60003760.
# Profit: 706000.0 ISK || Cost: 3651000.0 ISK
# Lowest sell: 3651000.0 Highest buy: 3584000.0 volume: 1
# Second sell: 4357000.0 ~ Margin: 706000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 49727 is a snipe at station: 60003760.
# Profit: 212700.0 ISK || Cost: 462000.0 ISK
# Lowest sell: 154000.0 Highest buy: 150600.0 volume: 3
# Second sell: 224900.0 ~ Margin: 70900.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 49731 is a snipe at station: 60003760.
# Profit: 125400.0 ISK || Cost: 1001400.0 ISK
# Lowest sell: 166900.0 Highest buy: 155000.0 volume: 6
# Second sell: 187800.0 ~ Margin: 20900.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 49735 is a snipe at station: 60003760.
# Profit: 148560.0 ISK || Cost: 270540.0 ISK
# Lowest sell: 45090.0 Highest buy: 32530.0 volume: 6
# Second sell: 69850.0 ~ Margin: 24760.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 50133 is a snipe at station: 60003760.
# Profit: 199900.0 ISK || Cost: 100000.0 ISK
# Lowest sell: 100000.0 Highest buy: 34200.0 volume: 1
# Second sell: 299900.0 ~ Margin: 199900.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 52200 is a snipe at station: 60003760.
# Profit: 215670.0 ISK || Cost: 36000.0 ISK
# Lowest sell: 12000.0 Highest buy: 366.9 volume: 3
# Second sell: 83890.0 ~ Margin: 71890.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 53040 is a snipe at station: 60003760.
# Profit: 999800.0 ISK || Cost: 800200.0 ISK
# Lowest sell: 800200.0 Highest buy: 800100.0 volume: 1
# Second sell: 1800000.0 ~ Margin: 999800.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 53381 is a snipe at station: 60003760.
# Profit: 277700.0 ISK || Cost: 222300.0 ISK
# Lowest sell: 222300.0 Highest buy: 200.0 volume: 1
# Second sell: 500000.0 ~ Margin: 277700.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 55303 is a snipe at station: 60003760.
# Profit: 3500000.0 ISK || Cost: 2000000.0 ISK
# Lowest sell: 2000000.0 Highest buy: 1768.0 volume: 1
# Second sell: 5500000.0 ~ Margin: 3500000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 55358 is a snipe at station: 60003760.
# Profit: 963000.0 ISK || Cost: 882000.0 ISK
# Lowest sell: 98000.0 Highest buy: 26470.0 volume: 9
# Second sell: 205000.0 ~ Margin: 107000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 55523 is a snipe at station: 60003760.
# Profit: 537600.0 ISK || Cost: 250100.0 ISK
# Lowest sell: 250100.0 Highest buy: 250000.0 volume: 1
# Second sell: 787700.0 ~ Margin: 537600.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 55546 is a snipe at station: 60003760.
# Profit: 935850.0 ISK || Cost: 65150.0 ISK
# Lowest sell: 65150.0 Highest buy: 65140.0 volume: 1
# Second sell: 1001000.0 ~ Margin: 935850.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 55547 is a snipe at station: 60003760.
# Profit: 150840.0 ISK || Cost: 10060.0 ISK
# Lowest sell: 10060.0 Highest buy: 10050.0 volume: 1
# Second sell: 160900.0 ~ Margin: 150840.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 55551 is a snipe at station: 60003760.
# Profit: 160000.0 ISK || Cost: 150000.0 ISK
# Lowest sell: 150000.0 Highest buy: 34370.0 volume: 1
# Second sell: 310000.0 ~ Margin: 160000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 55558 is a snipe at station: 60003760.
# Profit: 760980.0 ISK || Cost: 80020.0 ISK
# Lowest sell: 80020.0 Highest buy: 80010.0 volume: 1
# Second sell: 841000.0 ~ Margin: 760980.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 55586 is a snipe at station: 60003760.
# Profit: 406800.0 ISK || Cost: 126000.0 ISK
# Lowest sell: 42000.0 Highest buy: 6003.0 volume: 3
# Second sell: 177600.0 ~ Margin: 135600.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 55635 is a snipe at station: 60003760.
# Profit: 496800.0 ISK || Cost: 400000.0 ISK
# Lowest sell: 400000.0 Highest buy: 2800.0 volume: 1
# Second sell: 896800.0 ~ Margin: 496800.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 55661 is a snipe at station: 60003760.
# Profit: 222780.0 ISK || Cost: 16220.0 ISK
# Lowest sell: 16220.0 Highest buy: 16210.0 volume: 1
# Second sell: 239000.0 ~ Margin: 222780.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 55684 is a snipe at station: 60003760.
# Profit: 233690.0 ISK || Cost: 1010.0 ISK
# Lowest sell: 1010.0 Highest buy: 1009.0 volume: 1
# Second sell: 234700.0 ~ Margin: 233690.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 56733 is a snipe at station: 60003760.
# Profit: 850300.0 ISK || Cost: 650700.0 ISK
# Lowest sell: 650700.0 Highest buy: 650600.0 volume: 1
# Second sell: 1501000.0 ~ Margin: 850300.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 56861 is a snipe at station: 60003760.
# Profit: 25820000.0 ISK || Cost: 3280000.0 ISK
# Lowest sell: 3280000.0 Highest buy: 12310.0 volume: 1
# Second sell: 29100000.0 ~ Margin: 25820000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 62474 is a snipe at station: 60003760.
# Profit: 223076.0 ISK || Cost: 272800.0 ISK
# Lowest sell: 2200.0 Highest buy: 1999.0 volume: 124
# Second sell: 3999.0 ~ Margin: 1799.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 62640 is a snipe at station: 60003760.
# Profit: 2490000.0 ISK || Cost: 1000000.0 ISK
# Lowest sell: 1000000.0 Highest buy: 3531.0 volume: 1
# Second sell: 3490000.0 ~ Margin: 2490000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 63783 is a snipe at station: 60003760.
# Profit: 13500000.0 ISK || Cost: 1500000.0 ISK
# Lowest sell: 1500000.0 Highest buy: 0.02 volume: 1
# Second sell: 15000000.0 ~ Margin: 13500000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 64190 is a snipe at station: 60003760.
# Profit: 21820000.0 ISK || Cost: 1110000.0 ISK
# Lowest sell: 1110000.0 Highest buy: 3121.0 volume: 1
# Second sell: 22930000.0 ~ Margin: 21820000.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 76964 is a snipe at station: 60003760.
# Profit: 789900.0 ISK || Cost: 700100.0 ISK
# Lowest sell: 700100.0 Highest buy: 700000.0 volume: 1
# Second sell: 1490000.0 ~ Margin: 789900.0 ISK
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# Type ID 77418 is a snipe at station: 60003760.
# Profit: 123024.0 ISK || Cost: 440088.0 ISK
# Lowest sell: 5001.0 Highest buy: 5000.0 volume: 88
# Second sell: 6399.0 ~ Margin: 1398.0 ISK
# --------------------------------------------------------------------------
