# %%
import requests
import time

# %%
import os
import time
import json
import requests
import pandas as pd
from datetime import datetime
from requests.exceptions import HTTPError

# Constants
jita_station_id = 60003760  # Jita IV - Moon 4 - Caldari Navy Assembly Plant
base_url = "https://esi.evetech.net/latest"

def get_market_orders_jita(page=1):
    """
    Fetch market orders for Jita from ESI API.
    
    :param page: Page number for pagination.
    :return: JSON response containing market orders.
    """
    url = f"{base_url}/markets/10000002/orders/"
    params = {
        "order_type": "sell",
        "page": page,
        "structure_id": jita_station_id
    }
    
    response = requests.get(url, params=params)
    response.raise_for_status()  # This will raise an HTTPError for bad responses
    
    return response.json()

def download_all_orders():
    """
    Download all sell orders from Jita.
    
    :return: A list containing all market orders.
    """
    all_orders = []
    page = 1

    while True:
        try:
            orders = get_market_orders_jita(page)
            if not orders:
                break
            all_orders.extend(orders)
            print(f"Fetched page {page}, orders: {len(orders)}")
            page += 1
            time.sleep(1)  # Be polite to the API, limit request rate
        except HTTPError as e:
            if e.response.status_code == 404:
                print(f"Page {page} not found. Ending download.")
                break
            else:
                raise  # Re-raise the exception if it's not a 404 error
    
    return all_orders

# Download all orders
orders = download_all_orders()

# Convert the list of orders to a DataFrame
df = pd.DataFrame(orders)

# Get the current date and time
current_datetime = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Create the directory if it doesn't exist
output_dir = f'data/{current_datetime}'
os.makedirs(output_dir, exist_ok=True)

# Save the DataFrame to a CSV file in the directory
output_file = f"{output_dir}/jita_sell_orders.csv"
df.to_csv(output_file, index=False)

print(f"Total orders downloaded: {len(orders)}")
print(f"Orders saved to {output_file}")
# Out:
# Fetched page 1, orders: 1000
# Fetched page 2, orders: 1000
# Fetched page 3, orders: 1000
# Fetched page 4, orders: 1000
# Fetched page 5, orders: 1000
# Fetched page 6, orders: 1000
# Fetched page 7, orders: 1000
# Fetched page 8, orders: 1000
# Fetched page 9, orders: 1000
# Fetched page 10, orders: 1000
# Fetched page 11, orders: 1000
# Fetched page 12, orders: 1000
# Fetched page 13, orders: 1000
# Fetched page 14, orders: 1000
# Fetched page 15, orders: 1000
# Fetched page 16, orders: 1000
# Fetched page 17, orders: 1000
# Fetched page 18, orders: 1000
# Fetched page 19, orders: 1000
# Fetched page 20, orders: 1000
# Fetched page 21, orders: 1000
# Fetched page 22, orders: 1000
# Fetched page 23, orders: 1000
# Fetched page 24, orders: 1000
# Fetched page 25, orders: 1000
# Fetched page 26, orders: 1000
# Fetched page 27, orders: 1000
# Fetched page 28, orders: 1000
# Fetched page 29, orders: 1000
# Fetched page 30, orders: 1000
# Fetched page 31, orders: 1000
# Fetched page 32, orders: 1000
# Fetched page 33, orders: 1000
# Fetched page 34, orders: 1000
# Fetched page 35, orders: 1000
# Fetched page 36, orders: 1000
# Fetched page 37, orders: 1000
# Fetched page 38, orders: 1000
# Fetched page 39, orders: 1000
# Fetched page 40, orders: 1000
# Fetched page 41, orders: 1000
# Fetched page 42, orders: 1000
# Fetched page 43, orders: 1000
# Fetched page 44, orders: 1000
# Fetched page 45, orders: 1000
# Fetched page 46, orders: 1000
# Fetched page 47, orders: 1000
# Fetched page 48, orders: 1000
# Fetched page 49, orders: 1000
# Fetched page 50, orders: 1000
# Fetched page 51, orders: 1000
# Fetched page 52, orders: 1000
# Fetched page 53, orders: 1000
# Fetched page 54, orders: 1000
# Fetched page 55, orders: 1000
# Fetched page 56, orders: 1000
# Fetched page 57, orders: 1000
# Fetched page 58, orders: 1000
# Fetched page 59, orders: 1000
# Fetched page 60, orders: 1000
# Fetched page 61, orders: 1000
# Fetched page 62, orders: 1000
# Fetched page 63, orders: 1000
# Fetched page 64, orders: 1000
# Fetched page 65, orders: 1000
# Fetched page 66, orders: 1000
# Fetched page 67, orders: 1000
# Fetched page 68, orders: 1000
# Fetched page 69, orders: 1000
# Fetched page 70, orders: 1000
# Fetched page 71, orders: 1000
# Fetched page 72, orders: 1000
# Fetched page 73, orders: 1000
# Fetched page 74, orders: 1000
# Fetched page 75, orders: 1000
# Fetched page 76, orders: 1000
# Fetched page 77, orders: 1000
# Fetched page 78, orders: 1000
# Fetched page 79, orders: 1000
# Fetched page 80, orders: 1000
# Fetched page 81, orders: 1000
# Fetched page 82, orders: 1000
# Fetched page 83, orders: 1000
# Fetched page 84, orders: 1000
# Fetched page 85, orders: 1000
# Fetched page 86, orders: 1000
# Fetched page 87, orders: 1000
# Fetched page 88, orders: 1000
# Fetched page 89, orders: 1000
# Fetched page 90, orders: 1000
# Fetched page 91, orders: 1000
# Fetched page 92, orders: 1000
# Fetched page 93, orders: 1000
# Fetched page 94, orders: 1000
# Fetched page 95, orders: 1000
# Fetched page 96, orders: 1000
# Fetched page 97, orders: 1000
# Fetched page 98, orders: 1000
# Fetched page 99, orders: 1000
# Fetched page 100, orders: 1000
# Fetched page 101, orders: 1000
# Fetched page 102, orders: 1000
# Fetched page 103, orders: 1000
# Fetched page 104, orders: 1000
# Fetched page 105, orders: 1000
# Fetched page 106, orders: 1000
# Fetched page 107, orders: 1000
# Fetched page 108, orders: 1000
# Fetched page 109, orders: 1000
# Fetched page 110, orders: 1000
# Fetched page 111, orders: 1000
# Fetched page 112, orders: 1000
# Fetched page 113, orders: 1000
# Fetched page 114, orders: 1000
# Fetched page 115, orders: 1000
# Fetched page 116, orders: 1000
# Fetched page 117, orders: 1000
# Fetched page 118, orders: 1000
# Fetched page 119, orders: 1000
# Fetched page 120, orders: 1000
# Fetched page 121, orders: 1000
# Fetched page 122, orders: 1000
# Fetched page 123, orders: 1000
# Fetched page 124, orders: 1000
# Fetched page 125, orders: 1000
# Fetched page 126, orders: 1000
# Fetched page 127, orders: 1000
# Fetched page 128, orders: 1000
# Fetched page 129, orders: 1000
# Fetched page 130, orders: 1000
# Fetched page 131, orders: 1000
# Fetched page 132, orders: 1000
# Fetched page 133, orders: 1000
# Fetched page 134, orders: 1000
# Fetched page 135, orders: 1000
# Fetched page 136, orders: 1000
# Fetched page 137, orders: 1000
# Fetched page 138, orders: 1000
# Fetched page 139, orders: 1000
# Fetched page 140, orders: 1000
# Fetched page 141, orders: 1000
# Fetched page 142, orders: 1000
# Fetched page 143, orders: 1000
# Fetched page 144, orders: 1000
# Fetched page 145, orders: 1000
# Fetched page 146, orders: 1000
# Fetched page 147, orders: 1000
# Fetched page 148, orders: 1000
# Fetched page 149, orders: 1000
# Fetched page 150, orders: 1000
# Fetched page 151, orders: 1000
# Fetched page 152, orders: 1000
# Fetched page 153, orders: 1000
# Fetched page 154, orders: 1000
# Fetched page 155, orders: 1000
# Fetched page 156, orders: 1000
# Fetched page 157, orders: 1000
# Fetched page 158, orders: 1000
# Fetched page 159, orders: 1000
# Fetched page 160, orders: 1000
# Fetched page 161, orders: 1000
# Fetched page 162, orders: 1000
# Fetched page 163, orders: 1000
# Fetched page 164, orders: 1000
# Fetched page 165, orders: 1000
# Fetched page 166, orders: 1000
# Fetched page 167, orders: 1000
# Fetched page 168, orders: 1000
# Fetched page 169, orders: 1000
# Fetched page 170, orders: 1000
# Fetched page 171, orders: 1000
# Fetched page 172, orders: 1000
# Fetched page 173, orders: 1000
# Fetched page 174, orders: 1000
# Fetched page 175, orders: 1000
# Fetched page 176, orders: 1000
# Fetched page 177, orders: 1000
# Fetched page 178, orders: 1000
# Fetched page 179, orders: 1000
# Fetched page 180, orders: 1000
# Fetched page 181, orders: 1000
# Fetched page 182, orders: 1000
# Fetched page 183, orders: 1000
# Fetched page 184, orders: 1000
# Fetched page 185, orders: 1000
# Fetched page 186, orders: 1000
# Fetched page 187, orders: 1000
# Fetched page 188, orders: 1000
# Fetched page 189, orders: 1000
# Fetched page 190, orders: 1000
# Fetched page 191, orders: 1000
# Fetched page 192, orders: 1000
# Fetched page 193, orders: 1000
# Fetched page 194, orders: 1000
# Fetched page 195, orders: 1000
# Fetched page 196, orders: 1000
# Fetched page 197, orders: 1000
# Fetched page 198, orders: 1000
# Fetched page 199, orders: 1000
# Fetched page 200, orders: 1000
# Fetched page 201, orders: 1000
# Fetched page 202, orders: 1000
# Fetched page 203, orders: 1000
# Fetched page 204, orders: 1000
# Fetched page 205, orders: 1000
# Fetched page 206, orders: 1000
# Fetched page 207, orders: 1000
# Fetched page 208, orders: 1000
# Fetched page 209, orders: 1000
# Fetched page 210, orders: 1000
# Fetched page 211, orders: 1000
# Fetched page 212, orders: 1000
# Fetched page 213, orders: 1000
# Fetched page 214, orders: 1000
# Fetched page 215, orders: 1000
# Fetched page 216, orders: 1000
# Fetched page 217, orders: 1000
# Fetched page 218, orders: 1000
# Fetched page 219, orders: 1000
# Fetched page 220, orders: 1000
# Fetched page 221, orders: 1000
# Fetched page 222, orders: 1000
# Fetched page 223, orders: 1000
# Fetched page 224, orders: 1000
# Fetched page 225, orders: 1000
# Fetched page 226, orders: 1000
# Fetched page 227, orders: 1000
# Fetched page 228, orders: 1000
# Fetched page 229, orders: 1000
# Fetched page 230, orders: 1000
# Fetched page 231, orders: 1000
# Fetched page 232, orders: 1000
# Fetched page 233, orders: 1000
# Fetched page 234, orders: 1000
# Fetched page 235, orders: 1000
# Fetched page 236, orders: 1000
# Fetched page 237, orders: 147
# Page 238 not found. Ending download.
# Total orders downloaded: 236147
# Orders saved to data/2024-08-29_19-15-07/jita_sell_orders.csv

# %%
# Constants
jita_station_id = 60003760  # Jita IV - Moon 4 - Caldari Navy Assembly Plant
base_url = "https://esi.evetech.net/latest"

def get_market_orders_jita(page=1):
    """
    Fetch market orders for Jita from ESI API.
    
    :param page: Page number for pagination.
    :return: JSON response containing market orders.
    """
    url = f"{base_url}/markets/10000002/orders/"
    params = {
        "order_type": "sell",
        "page": page,
        "structure_id": jita_station_id
    }
    
    response = requests.get(url, params=params)
    response.raise_for_status()
    
    return response.json()

def download_all_orders():
    """
    Download all sell orders from Jita.
    
    :return: A list containing all market orders.
    """
    all_orders = []
    page = 1

    while True:
        orders = get_market_orders_jita(page)
        if not orders:
            break
        all_orders.extend(orders)
        print(f"Fetched page {page}, orders: {len(orders)}")
        page += 1
        time.sleep(1)  # Be polite to the API, limit request rate
    
    return all_orders

# Download all orders and save them to a file
orders = download_all_orders()

# Save to a JSON file
import json
with open('jita_sell_orders.json', 'w') as f:
    json.dump(orders, f)

print(f"Total orders downloaded: {len(orders)}")
# Out:
# Fetched page 1, orders: 1000
# Fetched page 2, orders: 1000
# Fetched page 3, orders: 1000
# Fetched page 4, orders: 1000
# Fetched page 5, orders: 1000
# Fetched page 6, orders: 1000
# Fetched page 7, orders: 1000
# Fetched page 8, orders: 1000
# Fetched page 9, orders: 1000
# Fetched page 10, orders: 1000
# Fetched page 11, orders: 1000
# Fetched page 12, orders: 1000
# Fetched page 13, orders: 1000
# Fetched page 14, orders: 1000
# Fetched page 15, orders: 1000
# Fetched page 16, orders: 1000
# Fetched page 17, orders: 1000
# Fetched page 18, orders: 1000
# Fetched page 19, orders: 1000
# Fetched page 20, orders: 1000
# Fetched page 21, orders: 1000
# Fetched page 22, orders: 1000
# Fetched page 23, orders: 1000
# Fetched page 24, orders: 1000
# Fetched page 25, orders: 1000
# Fetched page 26, orders: 1000
# Fetched page 27, orders: 1000
# Fetched page 28, orders: 1000
# Fetched page 29, orders: 1000
# Fetched page 30, orders: 1000
# Fetched page 31, orders: 1000
# Fetched page 32, orders: 1000
# Fetched page 33, orders: 1000
# Fetched page 34, orders: 1000
# Fetched page 35, orders: 1000
# Fetched page 36, orders: 1000
# Fetched page 37, orders: 1000
# Fetched page 38, orders: 1000
# Fetched page 39, orders: 1000
# Fetched page 40, orders: 1000
# Fetched page 41, orders: 1000
# Fetched page 42, orders: 1000
# Fetched page 43, orders: 1000
# Fetched page 44, orders: 1000
# Fetched page 45, orders: 1000
# Fetched page 46, orders: 1000
# Fetched page 47, orders: 1000
# Fetched page 48, orders: 1000
# Fetched page 49, orders: 1000
# Fetched page 50, orders: 1000
# Fetched page 51, orders: 1000
# Fetched page 52, orders: 1000
# Fetched page 53, orders: 1000
# Fetched page 54, orders: 1000
# Fetched page 55, orders: 1000
# Fetched page 56, orders: 1000
# Fetched page 57, orders: 1000
# Fetched page 58, orders: 1000
# Fetched page 59, orders: 1000
# Fetched page 60, orders: 1000
# Fetched page 61, orders: 1000
# Fetched page 62, orders: 1000
# Fetched page 63, orders: 1000
# Fetched page 64, orders: 1000
# Fetched page 65, orders: 1000
# Fetched page 66, orders: 1000
# Fetched page 67, orders: 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 45
#      42     return all_orders
#      44 # Download all orders and save them to a file
# ---> 45 orders = download_all_orders()
#      47 # Save to a JSON file
#      48 import json
#
# Cell In[2], line 40, in download_all_orders()
#      38     print(f"Fetched page {page}, orders: {len(orders)}")
#      39     page += 1
# ---> 40     time.sleep(1)  # Be polite to the API, limit request rate
#      42 return all_orders
#
# KeyboardInterrupt:
